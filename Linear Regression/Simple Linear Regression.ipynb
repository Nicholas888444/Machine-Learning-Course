# %% [markdown]
# # Simple Linear Regression
# Performing linear regression in Python is straightforward, thanks to libraries like NumPy, pandas, and scikit-learn. Here's a step-by-step guide on how to perform simple linear regression using these libraries:

# %% [markdown]
# ### Step 0: Install the necessary libraries

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.26.3)Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-2.1.4-cp310-cp310-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.7 MB 11.1 MB/s eta 0:00:01
#    ------ --------------------------------- 1.8/10.7 MB 19.6 MB/s eta 0:00:01
#    ------------ --------------------------- 3.3/10.7 MB 23.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.8/10.7 MB 25.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.3/10.7 MB 27.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.7/10.7 MB 27.3 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.7 MB 24.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.7 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.7 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 27.3 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ---------------------------------------- 0.0/502.5 kB ? eta -:--:--
#    --------------------------------------- 502.5/502.5 kB 30.8 MB/s eta 0:00:00
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.6 kB ? eta -:--:--
#    --------------------------------------- 346.6/346.6 kB 21.0 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.1.4 pytz-2023.3.post1 tzdata-2023.4

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\nick8\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.11.4)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.3.2-cp310-cp310-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.3 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/9.3 MB 7.1 MB/s eta 0:00:02
#    -------- ------------------------------- 1.9/9.3 MB 15.3 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.3 MB 19.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.3 MB 22.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.3 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.0/9.3 MB 27.0 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 26.9 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 26.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 22.8 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    --------------------------------------- 302.2/302.2 kB 18.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 threadpoolctl-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 1: Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Step 2: Load and explore your dataset

# %% [markdown]
# Assuming you have a dataset in a CSV file, you can load it using pandas:
#
# data = pd.read_csv('your_dataset.csv')
#
# In this tutorial, we will use an online dataset from https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv

# %%
data = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')

# %% [markdown]
# You can explore the dataset using commands like data.head() to see the first few rows or data.info() to get information about the columns and data types.

# %%
data.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %% [markdown]
# ### Step 3: Prepare your data

# %% [markdown]
# In simple linear regression, you typically have two columns: one for the independent variable (X) and another for the dependent variable (Y). You need to extract these columns from your dataset:
#
# X = data[['Independent_Variable_Column']]
#
# Y = data['Dependent_Variable_Column']
#
# Here we will use Experience Years as independent variable (X) and Salary as dependent variable (Y).

# %%
X = data[['Experience Years']]
Y = data['Salary']

# %% [markdown]
# ### Step 4: Create and fit the linear regression model

# %%
# Create a linear regression model
model = LinearRegression()

# Fit the model to your data
model.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# At this point, the model has calculated the optimal values for the coefficients (β0 and β1) using Least-Squares Estimation.

# %% [markdown]
# ### Step 5: Make predictions

# %% [markdown]
# You can use your trained model to make predictions for new or existing data points:

# %%
# Make predictions for X values
Y_pred = model.predict(X)

# %% [markdown]
# ### Step 6: Visualize the results

# %% [markdown]
# To visualize the regression line along with your data points:

# %%
# Plot the original data
plt.scatter(X, Y, label='Data')

# Plot the regression line
plt.plot(X, Y_pred, color='red', label='Linear Regression')

# Customize the plot
plt.xlabel('Independent Variable (Experience Years)')
plt.ylabel('Dependent Variable (Salary)')
plt.legend()
plt.show()

# %% [markdown]
# This will give you a scatter plot of your data with the regression line.

# %% [markdown]
# ### Step 7: Evaluate the model

# %% [markdown]
# You can evaluate the model's performance using metrics such as R-squared, Mean Squared Error (MSE), or Root Mean Squared Error (RMSE) to assess how well it fits the data.

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(Y, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y, Y_pred)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'R-squared (R²): {r2:.2f}')
# Out:
# Mean Squared Error (MSE): 28960383.65
# Root Mean Squared Error (RMSE): 5381.49
# R-squared (R²): 0.96
